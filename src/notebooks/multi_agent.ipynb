# %%
from crewai import Agent, Task, Crew
from crewai.tools import tool
from crewai.llm import LLM
from dotenv import load_dotenv
load_dotenv(override=True)
from datetime import datetime
now = datetime.now()

# %%
today = now.strftime('%d-%m-%Y')
print(today)
# Out:
# 29-06-2025

# %%
import requests
import os
chat_groq = LLM(model='groq/llama-3.3-70b-versatile')

serpa_api_key = os.environ.get('SERPA_API_KEY')

@tool('serpa search tool')
def get_serpa_search_data(search_query:str):
    """return google search using search query provided"""
    import http.client
    import json
    
    conn = http.client.HTTPSConnection("google.serper.dev")
    payload = json.dumps({
      "q": search_query
    })
    headers = {
      'X-API-KEY': serpa_api_key,
      'Content-Type': 'application/json'
    }
    conn.request("POST", "/search", payload, headers)
    res = conn.getresponse()
    data = res.read()
    search_data = data.decode("utf-8")
    print(search_data)
    return search_data

search_agent = Agent(llm=chat_groq,
                     role="Content Explorer",
                     tools=[get_serpa_search_data],
                     backstory="You are a content explorer . get latest information , latest news, interesting data for company name provided in  {search_query) provided.",
                     goal="get latest information , latest news, interesting data for company name provided {search_query) provided.",
                     max_iter=2,cache=True
                    )

# %%
search_task = Task(agent=search_agent,
                   expected_output="based on provided {search_query} you need to provide latest information , latest news, interesting data",
                   description="call tool with {search_query} as argument and provide latest information , latest news, interesting data using search")

# %%
# Text = "sARLA aVIATION https://www.sarla-aviation.com/"
# crew = Crew(agents=[search_agent], tasks=[search_task])
# result = crew.kickoff(inputs={'search_query': Text})
# print(result)
Script_Writer = Agent (
    role = 'Company Analyzer writter',
    goal = 'With the details given to you. analyze and write a good analysis about the company provided in {search_query}. latest investments, latest product launch ',
    llm=chat_groq,
    verbose = True,
    backstory = ('You are an expert company analyzer and provide report like economic times. You are very good in analyzing and writing company info\
                 Tell as a company analysis in 200 words.\
                 Consider you are on '+today),
)

create_a_analysis = Task (
                      description = "Considering the given details in time order make provide a complete company news and data",
                      expected_output = "A good company analysis",
                      agent = Script_Writer,
                      context = [search_task],
                      output_file = 'Script.txt'
                    )

# %%
from crewai import Crew, Process
from datetime import datetime

# Callback function to print a timestamp
def timestamp(Input):
    print(datetime.now())

# Define the crew with agents and tasks in sequential process
crew = Crew (
    agents = [search_agent, Script_Writer],
    tasks = [search_task, create_a_analysis],
    verbose = True,
    Process = Process.sequential,
    step_callback = timestamp
)
result = crew.kickoff (inputs={'search_query' : "sARLA aVIATION https://www.sarla-aviation.com/"})

print(result)
# Out:
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: f81d04a1-e503-4922-ba32-b1f4907bf839                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Content Explorer                                                     │
# │                                                                              │
# │  Task: call tool with sARLA aVIATION https://www.sarla-aviation.com/ as      │
# │  argument and provide latest information , latest news, interesting data     │
# │  using search                                                                │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# {"searchParameters":{"q":"sARLA aVIATION
# https://www.sarla-aviation.com/","type":"search","engine":"google"},"organic":[{
# "title":"SARLA
# AVIATION","link":"https://www.sarla-aviation.com/","snippet":"Sarla-Aviation is
# redefining the future of mass transportation by prioritizing safety,
# purpose-driven performance, and accessibility. Our commitment to these
# ...","position":1},{"title":"SARLA
# AVIATION","link":"https://www.sarla-aviation.com/home/","snippet":"We're
# developing India's most sophisticated eVTOL, driving innovation for widespread
# adoption in urban air mobility. Our focus is on creating an affordable,
# ...","position":2},{"title":"Sarla Aviation |
# LinkedIn","link":"https://in.linkedin.com/company/sarla-aviation","snippet":"Sar
# la Aviation. Aviation and Aerospace Component Manufacturing. Building a Viksit
# Bharat with flying taxis as the future of mass transportation.","date":"14 Feb
# 2025","position":3},{"title":"Sarla Aviation |
# LinkedIn","link":"https://www.linkedin.com/company/sarla-aviation","snippet":"We
# 're driving the future of mobility by making flying cars the heart of India's
# public transport, paving the way for faster, more accessible ...","date":"14 Feb
# 2025","position":4},{"title":"Sarla Aviation “to Launch Electric Air Taxi
# Services in Mumbai and
# ...","link":"https://evtolinsights.com/2025/04/sarla-aviation-to-launch-electric
# -air-taxi-services-in-mumbai-and-delhi/","snippet":"Schmidt now plans to launch
# Sarla's eVTOL aircraft in Mumbai and Delhi, after an initial introduction in
# Bengaluru. The company is gunning for a nationwide ...","date":"8 Apr
# 2025","position":5},{"title":"Contact - SARLA
# AVIATION","link":"https://www.sarla-aviation.com/legal/contact/","snippet":"hell
# o@sarla-aviation.com. Address: No 1090, 12th Main Rd, HAL 2nd Stage,
# Doopanahalli, Indiranagar, Bengaluru, Karnataka 560038, India. Inspiration.
# Newsletter.","position":6},{"title":"All About Sarla Aviation's Air Taxi | N18V
# | CNBCTV18 -
# YouTube","link":"https://www.youtube.com/watch?v=20q7QCvnm6I","snippet":"...
# https://youtube.com/live/P857H4ej-MQ SUBSCRIBE to our Channel: https ...
# 6-Seater, 20-Min Charging, Crash Prevention: All About Sarla Aviation's
# ...","date":"12 Feb 2025","position":7},{"title":"Sarla Aviation unveils its
# Shunya eVTOL at Bharat Mobility Global
# ...","link":"https://www.urbanairmobilitynews.com/air-taxis/sarala-aviation-unve
# ils-its-shunya-evtol-at-bharat-mobility-global-expo/","snippet":"The Shunya
# prototype is designed to carry up to six passengers on 20-30 km trips and can
# reach speeds of up to 250 kmph.","date":"20 Jan
# 2025","position":8},{"title":"Sarla Aviation to revolutionise urban mobility in
# India with electric
# ...","link":"https://infra.economictimes.indiatimes.com/news/urban-transportatio
# n/sarla-aviation-to-revolutionise-urban-mobility-in-india-with-electric-flying-t
# axis/114299474","snippet":"Sarla Aviation is leading the charge in transforming
# urban air mobility by developing cutting-edge electric vertical take-off and
# landing (eVTOL) ...","date":"17 Oct 2024","position":9},{"title":"sarla aviation
# on X: \"Not just a prototype- a preview of India's bright
# ...","link":"https://twitter.com/sarlaaviation/status/1909233059234246961","snip
# pet":"Not just a prototype- a preview of India's bright future! Sarla landed at
# #startupmahakumbh 🛩✨. Image. 1:13 PM · Apr 7, 2025.","date":"7 Apr
# 2025","position":10}],"credits":1}
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 2025-06-29 15:12:19.642865
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     └── 🔧 Used serpa search tool (1)
# ╭────────────────────────── 🔧 Agent Tool Execution ───────────────────────────╮
# │                                                                              │
# │  Agent: Content Explorer                                                     │
# │                                                                              │
# │  Thought: Thought: I need to find the latest information, news, and          │
# │  interesting data about sARLA aVIATION, so I should use the serpa search     │
# │  tool to search for this company and provide the latest content.             │
# │                                                                              │
# │  Using Tool: serpa search tool                                               │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────── Tool Input ─────────────────────────────────╮
# │                                                                              │
# │  "{\"search_query\": \"sARLA aVIATION https://www.sarla-aviation.com/\"}"    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# ╭──────────────────────────────── Tool Output ─────────────────────────────────╮
# │                                                                              │
# │  {"searchParameters":{"q":"sARLA aVIATION                                    │
# │  https://www.sarla-aviation.com/","type":"search","engine":"google"},"organ  │
# │  ic":[{"title":"SARLA                                                        │
# │  AVIATION","link":"https://www.sarla-aviation.com/","snippet":"Sarla-Aviati  │
# │  on is redefining the future of mass transportation by prioritizing safety,  │
# │  purpose-driven performance, and accessibility. Our commitment to these      │
# │  ...","position":1},{"title":"SARLA                                          │
# │  AVIATION","link":"https://www.sarla-aviation.com/home/","snippet":"We're    │
# │  developing India's most sophisticated eVTOL, driving innovation for         │
# │  widespread adoption in urban air mobility. Our focus is on creating an      │
# │  affordable, ...","position":2},{"title":"Sarla Aviation |                   │
# │  LinkedIn","link":"https://in.linkedin.com/company/sarla-aviation","snippet  │
# │  ":"Sarla Aviation. Aviation and Aerospace Component Manufacturing.          │
# │  Building a Viksit Bharat with flying taxis as the future of mass            │
# │  transportation.","date":"14 Feb 2025","position":3},{"title":"Sarla         │
# │  Aviation |                                                                  │
# │  LinkedIn","link":"https://www.linkedin.com/company/sarla-aviation","snippe  │
# │  t":"We're driving the future of mobility by making flying cars the heart    │
# │  of India's public transport, paving the way for faster, more accessible     │
# │  ...","date":"14 Feb 2025","position":4},{"title":"Sarla Aviation “to        │
# │  Launch Electric Air Taxi Services in Mumbai and                             │
# │  ...","link":"https://evtolinsights.com/2025/04/sarla-aviation-to-launch-el  │
# │  ectric-air-taxi-services-in-mumbai-and-delhi/","snippet":"Schmidt now       │
# │  plans to launch Sarla's eVTOL aircraft in Mumbai and Delhi, after an        │
# │  initial introduction in Bengaluru. The company is gunning for a nationwide  │
# │  ...","date":"8 Apr 2025","position":5},{"title":"Contact - SARLA            │
# │  AVIATION","link":"https://www.sarla-aviation.com/legal/contact/","snippet"  │
# │  :"hello@sarla-aviation.com. Address: No 1090, 12th Main Rd, HAL 2nd Stage,  │
# │  Doopanahalli, Indiranagar, Bengaluru, Karnataka 560038, India.              │
# │  Inspiration. Newsletter.","position":6},{"title":"All About Sarla           │
# │  Aviation's Air Taxi | N18V | CNBCTV18 -                                     │
# │  YouTube","link":"https://www.youtube.com/wat...                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 2025-06-29 15:12:19.667684
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     ├── 🔧 Used serpa search tool (1)
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 2025-06-29 15:12:23.544141
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Status: Executing Task...
#     └── 🔧 Used serpa search tool (1)
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Content Explorer                                                     │
# │                                                                              │
# │  Final Answer:                                                               │
# │  {"searchParameters":{"q":"sARLA aVIATION                                    │
# │  https://www.sarla-aviation.com/","type":"search","engine":"google"},"organ  │
# │  ic":[{"title":"SARLA                                                        │
# │  AVIATION","link":"https://www.sarla-aviation.com/","snippet":"Sarla-Aviati  │
# │  on is redefining the future of mass transportation by prioritizing safety,  │
# │  purpose-driven performance, and accessibility. Our commitment to these      │
# │  ...","position":1},{"title":"SARLA                                          │
# │  AVIATION","link":"https://www.sarla-aviation.com/home/","snippet":"We're    │
# │  developing India's most sophisticated eVTOL, driving innovation for         │
# │  widespread adoption in urban air mobility. Our focus is on creating an      │
# │  affordable, ...","position":2},{"title":"Sarla Aviation |                   │
# │  LinkedIn","link":"https://in.linkedin.com/company/sarla-aviation","snippet  │
# │  ":"Sarla Aviation. Aviation and Aerospace Component Manufacturing.          │
# │  Building a Viksit Bharat with flying taxis as the future of mass            │
# │  transportation.","date":"14 Feb 2025","position":3},{"title":"Sarla         │
# │  Aviation |                                                                  │
# │  LinkedIn","link":"https://www.linkedin.com/company/sarla-aviation","snippe  │
# │  t":"We're driving the future of mobility by making flying cars the heart    │
# │  of India's public transport, paving the way for faster, more accessible     │
# │  ...","date":"14 Feb 2025","position":4},{"title":"Sarla Aviation “to        │
# │  Launch Electric Air Taxi Services in Mumbai and                             │
# │  ...","link":"https://evtolinsights.com/2025/04/sarla-aviation-to-launch-el  │
# │  ectric-air-taxi-services-in-mumbai-and-delhi/","snippet":"Schmidt now       │
# │  plans to launch Sarla's eVTOL aircraft in Mumbai and Delhi, after an        │
# │  initial introduction in Bengaluru. The company is gunning for a nationwide  │
# │  ...","date":"8 Apr 2025","position":5},{"title":"Contact - SARLA            │
# │  AVIATION","link":"https://www.sarla-aviation.com/legal/contact/","snippet"  │
# │  :"hello@sarla-aviation.com. Address: No 1090, 12th Main Rd, HAL 2nd Stage,  │
# │  Doopanahalli, Indiranagar, Bengaluru, Karnataka 560038, India.              │
# │  Inspiration. Newsletter.","position":6},{"title":"All About Sarla           │
# │  Aviation's Air Taxi | N18V | CNBCTV18 -                                     │
# │  YouTube","link":"https://www.youtube.com/watch?v=20q7QCvnm6I","snippet":".  │
# │  .. https://youtube.com/live/P857H4ej-MQ SUBSCRIBE to our Channel: https     │
# │  ... 6-Seater, 20-Min Charging, Crash Prevention: All About Sarla            │
# │  Aviation's ...","date":"12 Feb 2025","position":7},{"title":"Sarla          │
# │  Aviation unveils its Shunya eVTOL at Bharat Mobility Global                 │
# │  ...","link":"https://www.urbanairmobilitynews.com/air-taxis/sarala-aviatio  │
# │  n-unveils-its-shunya-evtol-at-bharat-mobility-global-expo/","snippet":"The  │
# │   Shunya prototype is designed to carry up to six passengers on 20-30 km     │
# │  trips and can reach speeds of up to 250 kmph.","date":"20 Jan               │
# │  2025","position":8},{"title":"Sarla Aviation to revolutionise urban         │
# │  mobility in India with electric                                             │
# │  ...","link":"https://infra.economictimes.indiatimes.com/news/urban-transpo  │
# │  rtation/sarla-aviation-to-revolutionise-urban-mobility-in-india-with-elect  │
# │  ric-flying-taxis/114299474","snippet":"Sarla Aviation is leading the        │
# │  charge in transforming urban air mobility by developing cutting-edge        │
# │  electric vertical take-off and landing (eVTOL) ...","date":"17 Oct          │
# │  2024","position":9},{"title":"sarla aviation on X: \"Not just a prototype-  │
# │  a preview of India's bright                                                 │
# │  ...","link":"https://twitter.com/sarlaaviation/status/1909233059234246961"  │
# │  ,"snippet":"Not just a prototype- a preview of India's bright future!       │
# │  Sarla landed at #startupmahakumbh \ud83d\ude82\ud83d\udc9b. Image. 1:13 PM  │
# │  \u00b7 Apr 7, 2025.","date":"7 Apr 2025","position":10}],"credits":1}       │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
#     Assigned to: Content Explorer
#     Status: ✅ Completed
#     └── 🔧 Used serpa search tool (1)
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4                                  │
# │  Agent: Content Explorer                                                     │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: Company Analyzer writter                                             │
# │                                                                              │
# │  Task: Considering the given details in time order make provide a complete   │
# │  company news and data                                                       │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
# 2025-06-29 15:12:25.461625
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: Company Analyzer writter                                             │
# │                                                                              │
# │  Final Answer:                                                               │
# │  **Sarla Aviation: Revolutionizing Urban Mobility with Electric Air Taxis**  │
# │                                                                              │
# │  As of June 29, 2025, Sarla Aviation has been making significant strides in  │
# │  transforming the urban air mobility landscape in India. The company is      │
# │  pioneering the development of cutting-edge electric vertical take-off and   │
# │  landing (eVTOL) aircraft, designed to revolutionize the way people travel   │
# │  in urban areas.                                                             │
# │                                                                              │
# │  **Latest Developments**                                                     │
# │                                                                              │
# │  * Sarla Aviation has unveiled its Shunya eVTOL prototype, capable of        │
# │  carrying up to six passengers on trips of 20-30 km and reaching speeds of   │
# │  up to 250 kmph.                                                             │
# │  * The company plans to launch electric air taxi services in Mumbai and      │
# │  Delhi, following an initial introduction in Bengaluru, with a goal of       │
# │  expanding nationwide.                                                       │
# │  * Sarla Aviation has showcased its prototype at the Bharat Mobility Global  │
# │  Expo and the Startup Mahakumbh, generating significant interest and         │
# │  excitement in the industry.                                                 │
# │                                                                              │
# │  **Key Features of Sarla Aviation's eVTOL**                                  │
# │                                                                              │
# │  * 6-seater capacity                                                         │
# │  * 20-minute charging time                                                   │
# │  * Crash prevention system                                                   │
# │  * Designed for urban air mobility, with a focus on safety, accessibility,   │
# │  and affordability                                                           │
# │                                                                              │
# │  **Investments and Partnerships**                                            │
# │                                                                              │
# │  * While specific investment details are not publicly available, Sarla       │
# │  Aviation has been actively engaging with industry stakeholders,             │
# │  governments, and regulatory bodies to drive the adoption of eVTOL           │
# │  technology in India.                                                        │
# │                                                                              │
# │  **Product Launch**                                                          │
# │                                                                              │
# │  * Sarla Aviation is expected to launch its eVTOL aircraft in the near       │
# │  future, with a phased rollout planned for major cities in India.            │
# │  * The company's air taxi services are poised to transform the urban         │
# │  mobility landscape, offering a faster, more accessible, and sustainable     │
# │  mode of transportation.                                                     │
# │                                                                              │
# │  **Conclusion**                                                              │
# │                                                                              │
# │  Sarla Aviation is at the forefront of the urban air mobility revolution in  │
# │  India, with its cutting-edge eVTOL technology and commitment to safety,     │
# │  accessibility, and affordability. As the company continues to make          │
# │  significant strides in the development and deployment of its eVTOL          │
# │  aircraft, it is likely to have a profound impact on the way people travel   │
# │  in urban areas, shaping the future of transportation in India and beyond.   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: d5f2411a-2c82-4507-bdcd-ecb29e25dcd4
# │   Assigned to: Content Explorer
# │   Status: ✅ Completed
# │   └── 🔧 Used serpa search tool (1)
# └── 📋 Task: e3da59a1-fb39-43da-869f-803287fc23a3
#     Assigned to: Company Analyzer writter
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: e3da59a1-fb39-43da-869f-803287fc23a3                                  │
# │  Agent: Company Analyzer writter                                             │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: f81d04a1-e503-4922-ba32-b1f4907bf839                                    │
# │  Tool Args:                                                                  │
# │  Final Output: **Sarla Aviation: Revolutionizing Urban Mobility with         │
# │  Electric Air Taxis**                                                        │
# │                                                                              │
# │  As of June 29, 2025, Sarla Aviation has been making significant strides in  │
# │  transforming the urban air mobility landscape in India. The company is      │
# │  pioneering the development of cutting-edge electric vertical take-off and   │
# │  landing (eVTOL) aircraft, designed to revolutionize the way people travel   │
# │  in urban areas.                                                             │
# │                                                                              │
# │  **Latest Developments**                                                     │
# │                                                                              │
# │  * Sarla Aviation has unveiled its Shunya eVTOL prototype, capable of        │
# │  carrying up to six passengers on trips of 20-30 km and reaching speeds of   │
# │  up to 250 kmph.                                                             │
# │  * The company plans to launch electric air taxi services in Mumbai and      │
# │  Delhi, following an initial introduction in Bengaluru, with a goal of       │
# │  expanding nationwide.                                                       │
# │  * Sarla Aviation has showcased its prototype at the Bharat Mobility Global  │
# │  Expo and the Startup Mahakumbh, generating significant interest and         │
# │  excitement in the industry.                                                 │
# │                                                                              │
# │  **Key Features of Sarla Aviation's eVTOL**                                  │
# │                                                                              │
# │  * 6-seater capacity                                                         │
# │  * 20-minute charging time                                                   │
# │  * Crash prevention system                                                   │
# │  * Designed for urban air mobility, with a focus on safety, accessibility,   │
# │  and affordability                                                           │
# │                                                                              │
# │  **Investments and Partnerships**                                            │
# │                                                                              │
# │  * While specific investment details are not publicly available, Sarla       │
# │  Aviation has been actively engaging with industry stakeholders,             │
# │  governments, and regulatory bodies to drive the adoption of eVTOL           │
# │  technology in India.                                                        │
# │                                                                              │
# │  **Product Launch**                                                          │
# │                                                                              │
# │  * Sarla Aviation is expected to launch its eVTOL aircraft in the near       │
# │  future, with a phased rollout planned for major cities in India.            │
# │  * The company's air taxi services are poised to transform the urban         │
# │  mobility landscape, offering a faster, more accessible, and sustainable     │
# │  mode of transportation.                                                     │
# │                                                                              │
# │  **Conclusion**                                                              │
# │                                                                              │
# │  Sarla Aviation is at the forefront of the urban air mobility revolution in  │
# │  India, with its cutting-edge eVTOL technology and commitment to safety,     │
# │  accessibility, and affordability. As the company continues to make          │
# │  significant strides in the development and deployment of its eVTOL          │
# │  aircraft, it is likely to have a profound impact on the way people travel   │
# │  in urban areas, shaping the future of transportation in India and beyond.   │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# **Sarla Aviation: Revolutionizing Urban Mobility with Electric Air Taxis**
#
# As of June 29, 2025, Sarla Aviation has been making significant strides in transforming the urban air mobility landscape in India. The company is pioneering the development of cutting-edge electric vertical take-off and landing (eVTOL) aircraft, designed to revolutionize the way people travel in urban areas.
#
# **Latest Developments**
#
# * Sarla Aviation has unveiled its Shunya eVTOL prototype, capable of carrying up to six passengers on trips of 20-30 km and reaching speeds of up to 250 kmph.
# * The company plans to launch electric air taxi services in Mumbai and Delhi, following an initial introduction in Bengaluru, with a goal of expanding nationwide.
# * Sarla Aviation has showcased its prototype at the Bharat Mobility Global Expo and the Startup Mahakumbh, generating significant interest and excitement in the industry.
#
# **Key Features of Sarla Aviation's eVTOL**
#
# * 6-seater capacity
# * 20-minute charging time
# * Crash prevention system
# * Designed for urban air mobility, with a focus on safety, accessibility, and affordability
#
# **Investments and Partnerships**
#
# * While specific investment details are not publicly available, Sarla Aviation has been actively engaging with industry stakeholders, governments, and regulatory bodies to drive the adoption of eVTOL technology in India.
#
# **Product Launch**
#
# * Sarla Aviation is expected to launch its eVTOL aircraft in the near future, with a phased rollout planned for major cities in India.
# * The company's air taxi services are poised to transform the urban mobility landscape, offering a faster, more accessible, and sustainable mode of transportation.
#
# **Conclusion**
#
# Sarla Aviation is at the forefront of the urban air mobility revolution in India, with its cutting-edge eVTOL technology and commitment to safety, accessibility, and affordability. As the company continues to make significant strides in the development and deployment of its eVTOL aircraft, it is likely to have a profound impact on the way people travel in urban areas, shaping the future of transportation in India and beyond.
